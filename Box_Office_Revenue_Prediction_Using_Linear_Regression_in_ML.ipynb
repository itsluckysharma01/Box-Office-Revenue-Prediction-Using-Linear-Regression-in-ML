# %% [markdown]
#                                           Box Office Revenue Prediction Using Linear Regression in ML

# %% [markdown]
# # Box Office Revenue Prediction Using Linear Regression in ML
